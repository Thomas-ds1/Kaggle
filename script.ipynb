# %% [markdown]
# <a href="https://colab.research.google.com/github/Thomas-ds1/Kaggle/blob/main/script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
test = 213
